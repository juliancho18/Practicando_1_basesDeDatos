# %%
import pandas as pd

# %%
path="./input/Monitoreo_electrico_df.xlsx" #Sera igual a la direccion donde esta el archivo
df=pd.read_excel(f"{path}") #lee el archivo excel, el f string me guarda una variable texto  dentro del string

# %%
def leer_excel(path):# esta me define el nombre de la fucion y el argumento leido path
    df = pd.read_excel(path) # este me hace la funcion de leer archivo excel
    return df #me duvuelve el arvhico leido

# %%
df=leer_excel(path) #Vuelvo a llamar mi dato procesdado para ingresarlo al nuevo analisis

# %%
df
# Out:
#            ÍTEM ZONA           UBICACIÓN     TAG kW Nominal  Factor de Carga  \
# 0    2025-01-01  QSW      CLUSTER AMB 04  P-2046        500             0.46
# 1    2025-01-01  QSW      CLUSTER AMB 39  P-3029        300             0.59
# 2    2025-01-01  QSW      CLUSTER AMB 39  P-2027        300             0.00
# 3    2025-01-01  QSW      CLUSTER AMB 50  P-2045        500             0.73
# 4    2025-01-01  QSW      CLUSTER AMB 50  P-2057        500             0.00
# ...         ...  ...                 ...     ...        ...              ...
# 4260 2025-07-22  QSW      CLUSTER AMB 83  P-0289        400             0.00
# 4261 2025-07-22  QSW     CLUSTER AMAT-3D  P-3017        300             0.37
# 4262 2025-07-22  QSW     CLUSTER AMAT-10  P-2082         80             0.00
# 4263 2025-07-22  QSW  DESCARGADERO RB372  LEA053        500             0.56
# 4264 2025-07-22  QSW  DESCARGADERO RB372  P-2038        500             0.00
#
# ...

# %%
from libreria_julian import jrlibrerias
tarea=jrlibrerias()

# %%
df=tarea.leer_excel(path)

# %%
df
# Out:
#            ÍTEM ZONA           UBICACIÓN     TAG kW Nominal  Factor de Carga  \
# 0    2025-01-01  QSW      CLUSTER AMB 04  P-2046        500             0.46
# 1    2025-01-01  QSW      CLUSTER AMB 39  P-3029        300             0.59
# 2    2025-01-01  QSW      CLUSTER AMB 39  P-2027        300             0.00
# 3    2025-01-01  QSW      CLUSTER AMB 50  P-2045        500             0.73
# 4    2025-01-01  QSW      CLUSTER AMB 50  P-2057        500             0.00
# ...         ...  ...                 ...     ...        ...              ...
# 4260 2025-07-22  QSW      CLUSTER AMB 83  P-0289        400             0.00
# 4261 2025-07-22  QSW     CLUSTER AMAT-3D  P-3017        300             0.37
# 4262 2025-07-22  QSW     CLUSTER AMAT-10  P-2082         80             0.00
# 4263 2025-07-22  QSW  DESCARGADERO RB372  LEA053        500             0.56
# 4264 2025-07-22  QSW  DESCARGADERO RB372  P-2038        500             0.00
#
# ...
